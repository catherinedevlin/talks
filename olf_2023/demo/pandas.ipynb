# %%
import pandas as pd

# %%
df = pd.read_csv('../prep/supers.csv')
df
# Out:
#                 name    align                      tagline       based_in  \
# 0      The Trilobite      NaN               Caped Cambrian       Silvania
# 1          Putin Bae  villain          Rasslin’ Russophile      Mansfield
# 2    Cardinal Virtue     hero     Redbird of Righteousness     Cincinnati
# 3      Orville Wrong  villain              Fiend of Flight         Dayton
# 4       Wilbur Wrong  villain              Fiend of Flight         Dayton
# 5        Henry Fnord  villain      Mass-Producer of Mayhem       Dearborn
# 6    Nell Strongarm   villain                   Astro-Thug     Wapokoneta
# 7       The Thinker      hero                          NaN      Cleveland
# 8        Blue Jacket     hero                          NaN    Chillicothe
# 9   Captain Columbus     hero            Protector of Ohio       Columbus
# 10    Buckeye Bullet    hero      Literally Is Jesse Lewis      Cleveland
# 11      Annie Oakley     hero        Little Miss Sure Shot     Greenville
# ...

# %% [markdown]
# # filters

# %%
df[df.tagline.notna()]
# Out:
#                 name    align                      tagline     based_in  \
# 0      The Trilobite      NaN               Caped Cambrian     Silvania
# 1          Putin Bae  villain          Rasslin’ Russophile    Mansfield
# 2    Cardinal Virtue     hero     Redbird of Righteousness   Cincinnati
# 3      Orville Wrong  villain              Fiend of Flight       Dayton
# 4       Wilbur Wrong  villain              Fiend of Flight       Dayton
# 5        Henry Fnord  villain      Mass-Producer of Mayhem     Dearborn
# 6    Nell Strongarm   villain                   Astro-Thug   Wapokoneta
# 9   Captain Columbus     hero            Protector of Ohio     Columbus
# 11      Annie Oakley     hero        Little Miss Sure Shot   Greenville
# 13    Ohio Gosaimasu     hero             Sandusky Samurai     Sandusky
# 17  Captain Cuyahoga  villain        Fire and Water Do Mix    Cleveland
# 18       Indian Jane     hero  Nazi-punching archaeologist  Bloomington
#
# ...

# %% [markdown]
# # statistics

# %%
df.describe()
# Out:
#                  name    align          tagline   based_in power_1  \
# count              23       20               12         23      23
# unique             23        3               11         20      19
# top     The Trilobite  villain  Fiend of Flight  Cleveland  flight
# freq                1       10                2          3       2
#
#                  power_2              power_3
# count                 18                    4
# unique                17                    4
# top     armed ultralight  selective blindness
# freq                   2                    1

# %% [markdown]
# ## chaining

# %%
df[df.tagline.notna()].describe()
# Out:
#                  name    align          tagline based_in    power_1  \
# count              12       11               12       12         12
# unique             12        2               11       11         10
# top     The Trilobite  villain  Fiend of Flight   Dayton  invention
# freq                1        6                2        2          2
#
#                  power_2              power_3
# count                 12                    3
# unique                11                    3
# top     armed ultralight  selective blindness
# freq                   2                    1

# %% [markdown]
# # Pandas / SQL

# %%
df = pd.read_sql('select * from supers', 'postgresql://captcbus:forohio@localhost:5455/justice')

# %%
df.to_sql('supers', 'sqlite:///justice.sqlite', index=False, if_exists='replace')
# Out:
# 25

# %% [markdown]
# # [jupysql](https://jupysql.ploomber.io/en/latest/quick-start.html)

# %%
# %load_ext sql

# %%
# %sql sqlite:///justice.sqlite
# Out:
# Connecting and switching to connection sqlite:///justice.sqlite

# %%
# %%sql sqlite:///justice.sqlite
# SELECT  name, tagline, based_in
# FROM    supers
# WHERE   align = 'villain'
# Out:
# +------------------+-------------------------+------------+
# |       name       |         tagline         |  based_in  |
# +------------------+-------------------------+------------+
# |    Putin Bae     |   Rasslin’ Russophile   | Mansfield  |
# |  Orville Wrong   |     Fiend of Flight     |   Dayton   |
# |   Wilbur Wrong   |     Fiend of Flight     |   Dayton   |
# |   Henry Fnord    | Mass-Producer of Mayhem |  Dearborn  |
# |  Nell Strongarm  |        Astro-Thug       | Wapokoneta |
# |   The Stealer    |           None          | Pittsburgh |
# |  Airship Alice   |           None          |   Akron    |
# |  Motown Menace   |           None          |  Detroit   |
# | Captain Cuyahoga |  Fire and Water Do Mix  | Cleveland  |
# | Defiance Dogman  |           None          |  Defiance  |
# +------------------+-------------------------+------------+
# Truncated to displaylimit of 10.

# %%
clevelanders = %sql SELECT * FROM supers WHERE based_in = 'Cleveland'
# Out:
# Running query in 'sqlite:///justice.sqlite'

# %%
clevelanders
# Out:
# +----+------------------+---------+-----------------------+-----------+
# | id |       name       |  align  |        tagline        |  based_in |
# +----+------------------+---------+-----------------------+-----------+
# | 8  |   The Thinker    |   hero  |          None         | Cleveland |
# | 11 |  Buckeye Bullet  |   hero  |          None         | Cleveland |
# | 18 | Captain Cuyahoga | villain | Fire and Water Do Mix | Cleveland |
# +----+------------------+---------+-----------------------+-----------+

# %%
df = clevelanders.DataFrame()

# %%
df.name.max()
# Out:
# 'The Thinker'
